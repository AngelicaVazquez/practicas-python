# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelicaVazquez/practicas-python/blob/main/calcular_edad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

def calcular_edad():
  año_actual = datetime.now().year

  nombre = str(input("Introduce tu nombre: "))
  año_de_nacimiento = int(input("Introduce tu año de nacimiento: "))

  edad = año_actual - año_de_nacimiento

  print(f"{nombre}, tienes {edad} años")

calcular_edad()
